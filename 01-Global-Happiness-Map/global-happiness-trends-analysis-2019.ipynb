# %% [markdown]
# Exploratory Analysis: Based on the 2019 dataset, Finland is the happiest country in the world with the highest score. On the other hand, South Sudan is at the bottom of the list, indicating significant social and economic challenges in that region.

# %%
import pandas as pd
df_2019 = pd.read_csv('/kaggle/input/datasets/obaidhere/world-happiness-report/2019.csv')
print("2019 Happiness Data Loaded!")
df_2019.head()
# Out:
# 2019 Happiness Data Loaded!
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# ...
